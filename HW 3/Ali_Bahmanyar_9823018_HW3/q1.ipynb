# %%
import cv2
from matplotlib import pyplot

detector = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_alt2.xml")
image = cv2.imread("faces.jpg")
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

rects = detector.detectMultiScale(gray, scaleFactor=1.05,
	minNeighbors=7, minSize=(20, 20), flags=cv2.CASCADE_SCALE_IMAGE)

c = 0
for (x, y, w, h) in rects:
	cv2.rectangle(image, (x, y), (x + w, y + h), (0, 255, 0), 2)
	c += 1


pyplot.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB), cmap='gray')
pyplot.show()

print("Number of detected faces:", c)
# Out:
# Number of detected faces: 29
